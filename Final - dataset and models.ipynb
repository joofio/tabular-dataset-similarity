# %% [markdown]
# # V3 - 2024

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
import plotly.express as px
from final_function import *
#import seaborn as sns
#import scienceplots
#from matplotlib import pyplot as plt
#import matplotlib.pylab as plt
import json

#plt.style.use(['science','no-latex',"nature"])
#plt.style.use('science')

# %%
cv = KFold(n_splits=10)

# %% [markdown]
# # Data

# %%
#synth_data=pd.read_csv("synth_pop_2.csv",index_col=0,dtype=float).reset_index(drop=True)
real_data=pd.read_csv("real_data_testing.csv",index_col=0,dtype=float).reset_index(drop=True)
###variables
continuous_values = [
    "Age",
    "trestbps",
    "chol",
    "thalach",
    "oldpeak"
]
NA_REPLACE=["?"]

# %%
categorical_values = real_data[real_data.columns.difference(continuous_values)].columns

# %%
categorical_values
# Out:
# Index(['ca', 'cp', 'exang', 'fbs', 'num', 'restecg', 'sex', 'slope', 'thal'], dtype='object')

# %%
#newdata2
real_data2=pd.read_csv("real_data2_testing.csv",index_col=0,dtype=float).reset_index(drop=True)
real_data2.drop(columns=["id"],inplace=True)

continuous_values2=["Clump_Thickness","Uniformity_of_Cell_Size","Uniformity_of_Cell_Shape","Marginal_Adhesion","Single_Epithelial_Cell_Size","Bare_Nuclei","Bland_Chromatin","Normal_Nucleoli","Mitoses"]
categorical_values2 = real_data2[real_data2.columns.difference(continuous_values2)].columns
real_data2
# Out:
#      Clump_Thickness  Uniformity_of_Cell_Size  Uniformity_of_Cell_Shape  \
# 0                5.0                      1.0                       1.0
# 1                5.0                      4.0                       4.0
# 2                3.0                      1.0                       1.0
# 3                6.0                      8.0                       8.0
# 4                4.0                      1.0                       1.0
# ..               ...                      ...                       ...
# 694              3.0                      1.0                       1.0
# 695              2.0                      1.0                       1.0
# 696              5.0                     10.0                      10.0
# 697              4.0                      8.0                       6.0
# 698              4.0                      8.0                       8.0
#
#      Marginal_Adhesion  Single_Epithelial_Cell_Size  Bare_Nuclei  \
# ...

# %%
#newdata3
real_data3=pd.read_csv("real_data3_testing.csv",index_col=0,dtype=float).reset_index(drop=True)
continuous_values3=["mcv","alkphos","sgpt","sgot","gammagt","drinks"]
categorical_values3 = real_data3[real_data3.columns.difference(continuous_values3)].columns

# %%
#newdata4
real_data4=pd.read_csv("real_data4_testing.csv",index_col=0,dtype=float).reset_index(drop=True)
continuous_values4=["T3","TST","TSTRI","TSH","TMAX"]
categorical_values4 = real_data4[real_data4.columns.difference(continuous_values4)].columns

# %%
#newdata5
real_data5=pd.read_csv("real_data5_testing.csv",index_col=0,dtype=str).reset_index(drop=True)
continuous_values5=["Age_linear"]
categorical_values5 = real_data5[real_data5.columns.difference(continuous_values5)].columns
categorical_values5
# Out:
# Index(['PNL_infiltrate', 'acanthosis', 'band-like_infiltrate', 'class',
#        'clubbing_of_the_rete_ridges', 'definite_borders',
#        'disappearance_of_the_granular_layer', 'elongation_of_the_rete_ridges',
#        'eosinophils_in_the_infiltrate', 'erythema', 'exocytosis',
#        'family_history', 'fibrosis_of_the_papillary_dermis',
#        'focal_hypergranulosis', 'follicular_horn_plug', 'follicular_papules',
#        'hyperkeratosis', 'inflammatory_monoluclear_inflitrate', 'itching',
#        'knee_and_elbow_involvement', 'koebner_phenomenon',
#        'melanin_incontinence', 'munro_microabcess', 'oral_mucosal_involvement',
#        'parakeratosis', 'perifollicular_parakeratosis', 'polygonal_papules',
#        'saw-tooth_appearance_of_retes', 'scaling', 'scalp_involvement',
#        'spongiform_pustule', 'spongiosis',
#        'thinning_of_the_suprapapillary_epidermis',
#        'vacuolisation_and_damage_of_basal_layer'],
#       dtype='object')

# %%
#newdata6
real_data6=pd.read_csv("real_data6_testing.csv",index_col=0).reset_index(drop=True)

continuous_values6=[""]
categorical_values6 = real_data6[real_data6.columns.difference(continuous_values6)].columns
real_data6
# Out:
#      class  age  sex  histologic-type  degree-of-diffe  bone  bone-marrow  \
# 0        1    1    1                2                3     2            2
# 1        1    1    1                2                3     2            2
# 2        1    1    2                2                3     1            2
# 3        1    1    2                2                3     1            2
# 4        1    1    2                2                3     1            2
# ..     ...  ...  ...              ...              ...   ...          ...
# 334     22    2    2                2                3     2            2
# 335     22    2    2                2                3     2            2
# 336     22    2    2                2                3     1            2
# 337     22    3    2                2                2     2            2
# 338     22    3    2                2                2     2            2
#
#      lung  pleura  peritoneum  liver  brain  skin  neck  supraclavicular  \
# ...

# %% [markdown]
# # synth data 1

# %%
synth_data1=pd.read_csv("synth_pop_1.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
synth_data2=pd.read_csv("synth_pop_2.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
synth_data2.drop(columns=["id"],inplace=True)

# %%
result2=test_two_datasets(real_data2, synth_data2, categorical_values2   , continuous_values2, reps=10, seed=42)

# %%
synth_data3=pd.read_csv("synth_pop_3.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
result3=test_two_datasets(real_data3, synth_data3, categorical_values3   , continuous_values3, reps=10, seed=42)

# %%
synth_data4=pd.read_csv("synth_pop_4.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
result4=test_two_datasets(real_data4, synth_data4, categorical_values4   , continuous_values4, reps=10, seed=42)

# %%
synth_data5=pd.read_csv("synth_pop_5.csv",index_col=0,dtype=str).reset_index(drop=True)
synth_data5.rename(columns={"saw.tooth_appearance_of_retes":"saw-tooth_appearance_of_retes","band.like_infiltrate":"band-like_infiltrate"},inplace=True)

# %%
synth_data5

# %%
result5=test_two_datasets(real_data5, synth_data5, categorical_values5   , continuous_values5, reps=10, seed=42)

# %%
synth_result=[result,result2,result3,result4,result5]

# %%
import pickle 

with open('results/synth_result.pkl', 'wb') as f:
    pickle.dump(synth_result, f)

# %% [markdown]
# # Trials

# %% [markdown]
# ## Decision Tree

# %%
plot_data=trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=20)

# %%
# Writing to sample.json
with open("dt_1.json", "w") as outfile:
    json.dump(plot_data, outfile)

# %%
plot_data2=trial_permutatin(real_data2,categorical_values2,continuous_values2,cv,reps=20,nr_cols_to_test=5)

# %%
# Writing to sample.json
with open("dt_2.json", "w") as outfile:
    json.dump(plot_data2, outfile)

# %%
plot_data3=trial_permutatin(real_data3,categorical_values3,continuous_values3,cv,reps=20,nr_cols_to_test=4)

# %%
# Writing to sample.json
with open("dt_3.json", "w") as outfile:
    json.dump(plot_data3, outfile)

# %%
plot_data4=trial_permutatin(real_data4,categorical_values4,continuous_values4,cv,reps=20,nr_cols_to_test=4)

# %%
# Writing to sample.json
with open("dt_4.json", "w") as outfile:
    json.dump(plot_data4, outfile)

# %%
plot_data5=trial_permutatin(real_data5,categorical_values5,continuous_values5,cv,reps=20,nr_cols_to_test=15)

# %%
# Writing to sample.json
with open("dt_5.json", "w") as outfile:
    json.dump(plot_data5, outfile)

# %%
plot_data6=trial_permutatin(real_data6,categorical_values6,continuous_values6,cv,reps=20,nr_cols_to_test=9,models=[DecisionTreeClassifier(),DecisionTreeRegressor()])

# %%
# Writing to sample.json
with open("dt_6.json", "w") as outfile:
    json.dump(plot_data6, outfile)

# %% [markdown]
# ## Dataset1 Rest

# %%
plot_data_rf=trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=20,models=[RandomForestClassifier(),RandomForestRegressor()])
#145min

# %%
# Writing to sample.json
with open("rf_1.json", "w") as outfile:
    json.dump(plot_data_rf, outfile)

# %%
plot_data_knn=trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=20,models=[KNeighborsClassifier(),KNeighborsRegressor()])

# %%
# Writing to sample.json
with open("knn_1.json", "w") as outfile:
    json.dump(plot_data_knn, outfile)

# %%
plot_data_svm=trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=20,models=[SVC(),SVR()])

# %%
# Writing to sample.json
with open("SVM_1.json", "w") as outfile:
    json.dump(plot_data_svm, outfile)

# %%
plot_data_lm=trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=20,models=[LogisticRegression(solver="liblinear"),LinearRegression()])
#103min

# %%
# Writing to sample.json
with open("lm_1.json", "w") as outfile:
    json.dump(plot_data_lm, outfile)

# %%
from sklearn.linear_model import BayesianRidge
from sklearn.naive_bayes import GaussianNB 
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.svm import SVC,SVR
from sklearn.neighbors import KNeighborsRegressor,KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor

# %%
plot_data_nb=trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=20,models=[GaussianNB(),BayesianRidge()])
#107min

# %%
# Writing to sample.json
with open("nb_1.json", "w") as outfile:
    json.dump(plot_data_nb, outfile)

# %% [markdown]
# ## dataset 2 Rest

# %%
plot_data_rf2=trial_permutatin(real_data2,categorical_values2,continuous_values2,cv,reps=10,nr_cols_to_test=5,models=[RandomForestClassifier(),RandomForestRegressor()])
# Writing to sample.json
with open("rf_2.json", "w") as outfile:
    json.dump(plot_data_rf2, outfile)

# %%
plot_data_knn2=trial_permutatin(real_data2,categorical_values2,continuous_values2,cv,reps=20,nr_cols_to_test=5,models=[KNeighborsClassifier(),KNeighborsRegressor()])
# Writing to sample.json
with open("knn_2.json", "w") as outfile:
    json.dump(plot_data_knn2, outfile)

# %%
plot_data_svm2=trial_permutatin(real_data2,categorical_values2,continuous_values2,cv,reps=20,nr_cols_to_test=5,models=[SVC(),SVR()])
# Writing to sample.json
with open("svm_2.json", "w") as outfile:
    json.dump(plot_data_svm2, outfile)

# %%
plot_data_lm2=trial_permutatin(real_data2,categorical_values2,continuous_values2,cv,reps=20,nr_cols_to_test=5,models=[LogisticRegression(solver="liblinear"),LinearRegression()])
# Writing to sample.json
with open("lm_2.json", "w") as outfile:
    json.dump(plot_data_lm2, outfile)

# %%
plot_data_nb2=trial_permutatin(real_data2,categorical_values2,continuous_values2,cv,reps=20,nr_cols_to_test=5,models=[GaussianNB(),BayesianRidge()])
# Writing to sample.json
with open("nb_2.json", "w") as outfile:
    json.dump(plot_data_nb2, outfile)

# %% [markdown]
# ## dataset 3 Rest

# %%
plot_data_rf3=trial_permutatin(real_data3,categorical_values3,continuous_values3,cv,reps=20,nr_cols_to_test=4,models=[RandomForestClassifier(),RandomForestRegressor()])
with open("rf_3.json", "w") as outfile:
    json.dump(plot_data_rf3, outfile)

# %%
plot_data_knn3=trial_permutatin(real_data3,categorical_values3,continuous_values3,cv,reps=20,nr_cols_to_test=4,models=[KNeighborsClassifier(),KNeighborsRegressor()])
with open("knn_3.json", "w") as outfile:
    json.dump(plot_data_knn3, outfile)

# %%
plot_data_svm3=trial_permutatin(real_data3,categorical_values3,continuous_values3,cv,reps=20,nr_cols_to_test=4,models=[SVC(),SVR()])
with open("svm_3.json", "w") as outfile:
    json.dump(plot_data_svm3, outfile)

# %%
plot_data_lm3=trial_permutatin(real_data3,categorical_values3,continuous_values3,cv,reps=20,nr_cols_to_test=4,models=[LogisticRegression(solver="liblinear"),LinearRegression()])
with open("lm_3.json", "w") as outfile:
    json.dump(plot_data_lm3, outfile)

# %%
plot_data_nb3=trial_permutatin(real_data3,categorical_values3,continuous_values3,cv,reps=20,nr_cols_to_test=4,models=[GaussianNB(),BayesianRidge()])
with open("nb_3.json", "w") as outfile:
    json.dump(plot_data_nb3, outfile)

# %% [markdown]
# ## Dataset 4 Rest

# %%
plot_data_rf4=trial_permutatin(real_data4,categorical_values4,continuous_values4,cv,reps=20,nr_cols_to_test=4,models=[RandomForestClassifier(),RandomForestRegressor()])
with open("rf_4.json", "w") as outfile:
    json.dump(plot_data_rf4, outfile)

# %%
plot_data_knn4=trial_permutatin(real_data4,categorical_values4,continuous_values4,cv,reps=20,nr_cols_to_test=4,models=[KNeighborsClassifier(),KNeighborsRegressor()])
with open("knn_4.json", "w") as outfile:
    json.dump(plot_data_knn4, outfile)

# %%
plot_data_svm4=trial_permutatin(real_data4,categorical_values4,continuous_values4,cv,reps=20,nr_cols_to_test=4,models=[SVC(),SVR()])
with open("svm_4.json", "w") as outfile:
    json.dump(plot_data_svm4, outfile)

# %%
plot_data_lm4=trial_permutatin(real_data4,categorical_values4,continuous_values4,cv,reps=20,nr_cols_to_test=4,models=[LogisticRegression(solver="liblinear"),LinearRegression()])
with open("lm_4.json", "w") as outfile:
    json.dump(plot_data_lm4, outfile)

# %%
plot_data_nb4=trial_permutatin(real_data4,categorical_values4,continuous_values4,cv,reps=20,nr_cols_to_test=4,models=[GaussianNB(),BayesianRidge()])
with open("nb_4.json", "w") as outfile:
    json.dump(plot_data_nb4, outfile)

# %% [markdown]
# ## Dataset 5 Rest

# %%
plot_data_rf5=trial_permutatin(real_data5,categorical_values5,continuous_values5,cv,reps=20,nr_cols_to_test=15,models=[RandomForestClassifier(),RandomForestRegressor()])
with open("rf_5.json", "w") as outfile:
    json.dump(plot_data_rf5, outfile)
    #897min

# %%
plot_data_knn5=trial_permutatin(real_data5,categorical_values5,continuous_values5,cv,reps=20,nr_cols_to_test=15,models=[KNeighborsClassifier(),KNeighborsRegressor()])
with open("knn_5.json", "w") as outfile:
    json.dump(plot_data_knn5, outfile)

# %%
plot_data_svm5=trial_permutatin(real_data5,categorical_values5,continuous_values5,cv,reps=20,nr_cols_to_test=15,models=[SVC(),SVR()])
with open("svm_5.json", "w") as outfile:
    json.dump(plot_data_svm5, outfile)

# %%
plot_data_lm5=trial_permutatin(real_data5,categorical_values5,continuous_values5,cv,reps=20,nr_cols_to_test=15,models=[LogisticRegression(solver="liblinear"),LinearRegression()])
with open("lm_5.json", "w") as outfile:
    json.dump(plot_data_lm5, outfile)

# %%
plot_data_nb5=trial_permutatin(real_data5,categorical_values5,continuous_values5,cv,reps=20,nr_cols_to_test=15,models=[GaussianNB(),BayesianRidge()])
with open("nb_5.json", "w") as outfile:
    json.dump(plot_data_nb5, outfile)

# %% [markdown]
# ## dataset6 Rest

# %%
plot_data_rf6=trial_permutatin(real_data6,categorical_values6,continuous_values6,cv,reps=20,nr_cols_to_test=9,models=[RandomForestClassifier(),RandomForestRegressor()])
with open("rf_6.json", "w") as outfile:
    json.dump(plot_data_rf6, outfile)

# %%
plot_data_knn6=trial_permutatin(real_data6,categorical_values6,continuous_values6,cv,reps=20,nr_cols_to_test=9,models=[KNeighborsClassifier(),KNeighborsRegressor()])
with open("knn_6.json", "w") as outfile:
    json.dump(plot_data_knn6, outfile)

# %%
plot_data_svm6=trial_permutatin(real_data6,categorical_values6,continuous_values6,cv,reps=20,nr_cols_to_test=9,models=[SVC(),SVR()])
with open("svm_6.json", "w") as outfile:
    json.dump(plot_data_svm6, outfile)

# %%
plot_data_lm6=trial_permutatin(real_data6,categorical_values6,continuous_values6,cv,reps=20,nr_cols_to_test=9,models=[LogisticRegression(solver="liblinear"),LinearRegression()])
with open("lm_6.json", "w") as outfile:
    json.dump(plot_data_lm6, outfile)

# %%
plot_data_nb6=trial_permutatin(real_data6,categorical_values6,continuous_values6,cv,reps=20,nr_cols_to_test=9,models=[GaussianNB(),BayesianRidge()])
with open("nb_6.json", "w") as outfile:
    json.dump(plot_data_nb6, outfile)

# %% [markdown]
# # Synth data 1 Testing

# %%
result=test_two_datasets(real_data, synth_data1, categorical_values, continuous_values, reps=10, seed=42)

# %%
synth_data2=pd.read_csv("synth_pop_2.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
synth_data2.drop(columns=["id"],inplace=True)

# %%
result2=test_two_datasets(real_data2, synth_data2, categorical_values2   , continuous_values2, reps=10, seed=42)

# %%
synth_data3=pd.read_csv("synth_pop_3.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
result3=test_two_datasets(real_data3, synth_data3, categorical_values3   , continuous_values3, reps=10, seed=42)

# %%
synth_data4=pd.read_csv("synth_pop_4.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
result4=test_two_datasets(real_data4, synth_data4, categorical_values4   , continuous_values4, reps=10, seed=42)

# %%
synth_data5=pd.read_csv("synth_pop_5.csv",index_col=0,dtype=str).reset_index(drop=True)
synth_data5.rename(columns={"saw.tooth_appearance_of_retes":"saw-tooth_appearance_of_retes","band.like_infiltrate":"band-like_infiltrate"},inplace=True)

# %%
synth_data5

# %%
real_data5

# %%
result5=test_two_datasets(real_data5, synth_data5, categorical_values5   , continuous_values5, reps=10, seed=42)

# %%
synth_result=[result,result2,result3,result4,result5]

# %%
import pickle 

with open('results/synth_result.pkl', 'wb') as f:
    pickle.dump(synth_result, f)

# %% [markdown]
# # synth data testing - CTGAN

# %%
synth_data1_ctgan=pd.read_csv("synth1_ctgan.csv",index_col=0,dtype=float).reset_index(drop=True)

synth_data1_ctgan.replace("?", np.nan,inplace=True)

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
x_cont=imp_mean.fit_transform(synth_data1_ctgan[continuous_values])
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
x_cat=imp_mean.fit_transform(synth_data1_ctgan[categorical_values])

synth_data1_ctgan[continuous_values]=pd.DataFrame(x_cont,columns=continuous_values)
synth_data1_ctgan[categorical_values]=pd.DataFrame(x_cat,columns=categorical_values)

result=test_two_datasets(real_data, synth_data1_ctgan, categorical_values, continuous_values, reps=10, seed=42)
# Out:
# {'Age': 0.9143594774048784, 'sex': 1.069079321725276, 'cp': 0.8327332733273328, 'trestbps': 0.6443471214112383, 'chol': 1.8270208902742031, 'fbs': 1.0109771846749893, 'restecg': 0.9327832783278328, 'thalach': 0.6020829793028907, 'exang': 1.084531033748536, 'oldpeak': 0.8967701375425089, 'slope': 1.01498899889989, 'ca': 0.9756283320639756, 'thal': 1.0549174917491748, 'num': 0.8763346922927588}
# {'Age': 2.214475846692597, 'sex': 0.8455445544554455, 'cp': 0.6344634463446344, 'trestbps': 3.1408373181101914, 'chol': 1.7790984980658673, 'fbs': 0.7515951595159516, 'restecg': 1.0506394389438944, 'thalach': 3.0022684983705523, 'exang': 0.7758190453191661, 'oldpeak': 5.074901689234077, 'slope': 0.5941399017950576, 'ca': 0.698329207920792, 'thal': 0.9688531353135313, 'num': 0.5823903818953324}

# %%
synth_data2_ctgan=pd.read_csv("synth2_ctgan.csv",index_col=0).reset_index(drop=True)
synth_data2_ctgan.replace("?", np.nan,inplace=True)
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
x_cont=imp_mean.fit_transform(synth_data2_ctgan[continuous_values2])
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
x_cat=imp_mean.fit_transform(synth_data2_ctgan[categorical_values2])

synth_data2_ctgan[continuous_values2]=pd.DataFrame(x_cont,columns=continuous_values2)
synth_data2_ctgan[categorical_values2]=pd.DataFrame(x_cat,columns=categorical_values2)
synth_data2_ctgan=synth_data2_ctgan.astype(float)

# %%
result2=test_two_datasets(real_data2, synth_data2_ctgan, categorical_values2   , continuous_values2, reps=10, seed=42)
# Out:
# {'Clump_Thickness': 1.0046342501054015, 'Uniformity_of_Cell_Size': 1.1714210495684372, 'Uniformity_of_Cell_Shape': 1.2318207321487453, 'Marginal_Adhesion': 0.7703125648356722, 'Single_Epithelial_Cell_Size': 0.7090001331749357, 'Bare_Nuclei': 0.6571505334551834, 'Bland_Chromatin': 1.2102788413497363, 'Normal_Nucleoli': 0.5135024137425153, 'Mitoses': 0.6192062483321158, 'Class': 0.8869814020028611}
# {'Clump_Thickness': 3.2939818752867756, 'Uniformity_of_Cell_Size': 8.405602795425567, 'Uniformity_of_Cell_Shape': 8.217875102489346, 'Marginal_Adhesion': 4.457594698163798, 'Single_Epithelial_Cell_Size': 4.9965009733316785, 'Bare_Nuclei': 5.124207245374274, 'Bland_Chromatin': 3.747918267627082, 'Normal_Nucleoli': 3.0144894144457024, 'Mitoses': 4.136874014724096, 'Class': 0.5735466250487711}

# %%
synth_data3_ctgan=pd.read_csv("synth3_ctgan.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
result3=test_two_datasets(real_data3, synth_data3_ctgan, categorical_values3   , continuous_values3, reps=10, seed=42)
# Out:
# {'mcv': 1.086632104086992, 'alkphos': 0.7259334093926126, 'sgpt': 0.9702925061286336, 'sgot': 0.9064637084796647, 'gammagt': 0.9053436963679753, 'drinks': 1.4242172249495533, 'Selector': 0.9244444444444445}
# {'mcv': 2.7836048722864457, 'alkphos': 1.8320647291239203, 'sgpt': 3.2213358698051398, 'sgot': 3.6691546436759235, 'gammagt': 1.9784347706967393, 'drinks': 1.5331123245747085, 'Selector': 0.7822222222222222}

# %%
synth_data4_ctgan=pd.read_csv("synth4_ctgan.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
result4=test_two_datasets(real_data4, synth_data4_ctgan, categorical_values4   , continuous_values4, reps=10, seed=42)
# Out:
# {'Class': 2.2399999999999998, 'T3': 0.28070355513450485, 'TST': 0.636399963148891, 'TSTRI': 0.7970354653255194, 'TSH': 0.3268380839302606, 'TMAX': 0.5822560856361477}
# {'Class': 0.38571428571428573, 'T3': 3.7532593375337755, 'TST': 3.710594356606933, 'TSTRI': 7.698962964214, 'TSH': 7.8176583398957105, 'TMAX': 3.1047439071288134}

# %%
synth_data6_ctgan=pd.read_csv("synth6_ctgan2.csv",index_col=0,dtype=str).reset_index(drop=True)


synth_data6_ctgan.replace("?", np.nan,inplace=True)

from sklearn.impute import SimpleImputer
#imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
#x_cont=imp_mean.fit_transform(synth_data6_ctgan[continuous_values6])
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
x_cat=imp_mean.fit_transform(synth_data6_ctgan[categorical_values6])

#synth_data6_ctgan[continuous_values6]=pd.DataFrame(x_cont,columns=continuous_values6)
synth_data6_ctgan[categorical_values6]=pd.DataFrame(x_cat,columns=categorical_values6)

# %%
result6=test_two_datasets(real_data6, synth_data6_ctgan, categorical_values6  , continuous_values6, reps=10, seed=42)
# Out:
# {'class': 1.1799410029498525, 'age': 0.9692372524230931, 'sex': 1.0458567980691873, 'histologic-type': 0.9347584568823507, 'degree-of-diffe': 1.0619469026548671, 'bone': 0.9926487802593998, 'bone-marrow': 0.9934736423800572, 'lung': 1.0190399570930546, 'pleura': 0.9068968039201345, 'peritoneum': 0.7979109241259248, 'liver': 1.0350359674998706, 'brain': 1.0173098383204007, 'skin': 1.0524782402855166, 'neck': 1.0177497997952336, 'supraclavicular': 1.0274011014278184, 'axillar': 1.0363297624592454, 'mediastinum': 1.1279612230842202, 'abdominal': 1.123213070115725}
# ...

# %%
synth_result=[result,result2,result3,result4,result6]

# %%
import pickle 

with open('results/synth_result_Ctgan.pkl', 'wb') as f:
    pickle.dump(synth_result, f)

# %% [markdown]
# # synth data testing - Gaussian Copula

# %%
synth_data1_gaussian=pd.read_csv("synth1_gaussian.csv",index_col=0,dtype=float).reset_index(drop=True)

synth_data1_gaussian.replace("?", np.nan,inplace=True)

from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
x_cont=imp_mean.fit_transform(synth_data1_gaussian[continuous_values])
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
x_cat=imp_mean.fit_transform(synth_data1_gaussian[categorical_values])

synth_data1_gaussian[continuous_values]=pd.DataFrame(x_cont,columns=continuous_values)
synth_data1_gaussian[categorical_values]=pd.DataFrame(x_cat,columns=categorical_values)

result=test_two_datasets(real_data, synth_data1_gaussian, categorical_values, continuous_values, reps=10, seed=42)
# Out:
# {'Age': 0.8534216801707825, 'sex': 1.1701732673267327, 'cp': 1.0513384671800512, 'trestbps': 0.6418072654676101, 'chol': 1.012857929269147, 'fbs': 1.0615061506150616, 'restecg': 0.9596259625962597, 'thalach': 0.7128931023688643, 'exang': 0.7940960762742941, 'oldpeak': 0.8509155926063822, 'slope': 1.050365906155833, 'ca': 0.9171250458379172, 'thal': 1.1107317628314555, 'num': 0.9663366336633663}
# {'Age': 3.1688081715714222, 'sex': 0.85001833516685, 'cp': 0.6222622262226223, 'trestbps': 3.8499606204702594, 'chol': 1.412040897029217, 'fbs': 0.85001833516685, 'restecg': 0.8681930693069306, 'thalach': 3.575246973048819, 'exang': 0.770908798196893, 'oldpeak': 4.273252774434328, 'slope': 0.5450374305723256, 'ca': 0.6731641914191419, 'thal': 0.8241542904290429, 'num': 0.7046204620462045}

# %%
synth_data2_gaussian=pd.read_csv("synth2_gaussian.csv",index_col=0).reset_index(drop=True)
synth_data2_gaussian.replace("?", np.nan,inplace=True)
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
x_cont=imp_mean.fit_transform(synth_data2_gaussian[continuous_values2])
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
x_cat=imp_mean.fit_transform(synth_data2_gaussian[categorical_values2])

synth_data2_gaussian[continuous_values2]=pd.DataFrame(x_cont,columns=continuous_values2)
synth_data2_gaussian[categorical_values2]=pd.DataFrame(x_cat,columns=categorical_values2)
synth_data2_gaussian=synth_data2_gaussian.astype(float)

# %%
result2=test_two_datasets(real_data2, synth_data2_gaussian, categorical_values2   , continuous_values2, reps=10, seed=42)
# Out:
# {'Clump_Thickness': 0.8199086560136952, 'Uniformity_of_Cell_Size': 0.32931732602867547, 'Uniformity_of_Cell_Shape': 0.3569130236458147, 'Marginal_Adhesion': 0.46323423782693357, 'Single_Epithelial_Cell_Size': 0.506503282577501, 'Bare_Nuclei': 0.6981022892906242, 'Bland_Chromatin': 0.5678167802225077, 'Normal_Nucleoli': 0.3707184798293505, 'Mitoses': 1.248797799096344, 'Class': 1.2577107080775916}
# {'Clump_Thickness': 3.169793651589084, 'Uniformity_of_Cell_Size': 5.894415820469261, 'Uniformity_of_Cell_Shape': 5.564648741497292, 'Marginal_Adhesion': 2.9744082458101744, 'Single_Epithelial_Cell_Size': 3.2735971532456634, 'Bare_Nuclei': 3.71306372094915, 'Bland_Chromatin': 2.8456143624051293, 'Normal_Nucleoli': 1.9027450637525534, 'Mitoses': 1.6457983411441262, 'Class': 0.7161746217540209}

# %%
synth_data3_gaussian=pd.read_csv("synth3_gaussian.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
result3=test_two_datasets(real_data3, synth_data3_gaussian, categorical_values3   , continuous_values3, reps=10, seed=42)
# Out:
# {'mcv': 0.8940670604017261, 'alkphos': 1.032018044169734, 'sgpt': 1.848562701782134, 'sgot': 0.697859156319841, 'gammagt': 1.2945735066044237, 'drinks': inf, 'Selector': 0.9631578947368422}
# {'mcv': 1.928622317249402, 'alkphos': 0.7566052183266718, 'sgpt': 0.6199589838703015, 'sgot': 0.7045355975549371, 'gammagt': 0.4479159282544782, 'drinks': 1.366374164953484, 'Selector': 0.8711111111111112}
# /Users/joaoalmeida/Library/CloudStorage/OneDrive-Pessoal/HEADS/05. TESE/8.0 dataset similarity/tabular-dataset-similarity/final_function.py:79: RuntimeWarning: divide by zero encountered in scalar divide
#   result[r_cols[i]] = real_synth / real_real

# %%
synth_data4_gaussian=pd.read_csv("synth4_gaussian.csv",index_col=0,dtype=float).reset_index(drop=True)

# %%
result4=test_two_datasets(real_data4, synth_data4_gaussian, categorical_values4, continuous_values4, reps=10, seed=42)
# Out:
# {'Class': 1.1833333333333333, 'T3': 0.9007762916231639, 'TST': 1.1186617879302716, 'TSTRI': 1.4170617027197177, 'TSH': 4.570791395861895, 'TMAX': 2.222477578664866}
# {'Class': 0.5190476190476191, 'T3': 0.8745491042232467, 'TST': 0.7487345686417854, 'TSTRI': 0.9094377207966379, 'TSH': 1.2942158405208506, 'TMAX': 1.0648936571240717}

# %%
synth_data6_gaussian=pd.read_csv("synth6_gaussian2.csv",index_col=0,dtype=str).reset_index(drop=True)


synth_data6_gaussian.replace("?", np.nan,inplace=True)

from sklearn.impute import SimpleImputer
#imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
#x_cont=imp_mean.fit_transform(synth_data6_ctgan[continuous_values6])
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
x_cat=imp_mean.fit_transform(synth_data6_gaussian[categorical_values6])

#synth_data6_ctgan[continuous_values6]=pd.DataFrame(x_cont,columns=continuous_values6)
synth_data6_gaussian[categorical_values6]=pd.DataFrame(x_cat,columns=categorical_values6)

# %%
result6=test_two_datasets(real_data6, synth_data6_gaussian, categorical_values6  , continuous_values6, reps=10, seed=42)
# Out:
# {'class': 2.1516571230262014, 'age': 1.0122651762148736, 'sex': 1.1438203600024082, 'histologic-type': 1.0271428874599435, 'degree-of-diffe': 0.9478214613859471, 'bone': 1.0199490025498725, 'bone-marrow': 0.9967396367023755, 'lung': 0.9277398725483573, 'pleura': 1.2168141592920352, 'peritoneum': 1.0891763104152485, 'liver': 1.27826941986234, 'brain': 1.062679785265395, 'skin': 0.9989273263609546, 'neck': 0.9885992186877143, 'supraclavicular': 1.0747524639271913, 'axillar': 1.063450012212765, 'mediastinum': 1.0107246575655713, 'abdominal': 0.8777609899992804}
# ...

# %%
synth_result=[result,result2,result3,result4,result6]

# %%
import pickle 

with open('results/synth_result_gaussian.pkl', 'wb') as f:
    pickle.dump(synth_result, f)

# %% [markdown]
# # Nrs of runs

# %%
cv = KFold(n_splits=10)

# %%
bigger_plot_data=[]

# %%
for i in range(5,20,5):
    #print(i)
    bigger_plot_data.append(trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger_p1.json", "w") as outfile:
    json.dump(bigger_plot_data, outfile)

# %%
for i in range(20,30,5):
    print(i)
    bigger_plot_data.append(trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger_p2.json", "w") as outfile:
    json.dump(bigger_plot_data, outfile)

# %%
for i in range(30,35,5):
    print(i)
    bigger_plot_data.append(trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger_p3.json", "w") as outfile:
    json.dump(bigger_plot_data, outfile)

# %%
for i in range(35,40,5):
    print(i)
    bigger_plot_data.append(trial_permutatin(real_data,categorical_values,continuous_values,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger_p4.json", "w") as outfile:
    json.dump(bigger_plot_data, outfile)

# %%
bigger_plot_data2=[]
for i in range(5,20,5):
    #print(i)
    bigger_plot_data2.append(trial_permutatin(real_data2,categorical_values2,continuous_values2,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger2_p1.json", "w") as outfile:
    json.dump(bigger_plot_data2, outfile)

# %%
for i in range(20,35,5):
    print(i)
    bigger_plot_data2.append(trial_permutatin(real_data2,categorical_values2,continuous_values2,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger2_p2.json", "w") as outfile:
    json.dump(bigger_plot_data2, outfile)

# %%
for i in range(35,40,5):
    print(i)
    bigger_plot_data2.append(trial_permutatin(real_data2,categorical_values2,continuous_values2,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger2_p3.json", "w") as outfile:
    json.dump(bigger_plot_data2, outfile)

# %%
bigger_plot_data3=[]
for i in range(5,20,5):
    #print(i)
    bigger_plot_data3.append(trial_permutatin(real_data3,categorical_values3,continuous_values3,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger3_p1.json", "w") as outfile:
    json.dump(bigger_plot_data3, outfile)

# %%
for i in range(20,35,5):
    print(i)
    bigger_plot_data3.append(trial_permutatin(real_data3,categorical_values3,continuous_values3,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger3_p2.json", "w") as outfile:
    json.dump(bigger_plot_data3, outfile)

# %%
for i in range(35,40,5):
    print(i)
    bigger_plot_data3.append(trial_permutatin(real_data3,categorical_values3,continuous_values3,cv,reps=i))

# %%
# Writing to sample.json
with open("results/bigger3_p3.json", "w") as outfile:
    json.dump(bigger_plot_data3, outfile)

# %%
### 4

# %%
bigger_plot_data4=[]
for i in range(5,20,5):
    #print(i)
    bigger_plot_data4.append(trial_permutatin(real_data4,categorical_values4,continuous_values4,cv,reps=i,nr_cols_to_test=4))
# Writing to sample.json
with open("results/bigger4_p1.json", "w") as outfile:
    json.dump(bigger_plot_data4, outfile)


for i in range(20,35,5):
    print(i)
    bigger_plot_data4.append(trial_permutatin(real_data4,categorical_values4,continuous_values4,cv,reps=i,nr_cols_to_test=4))
# Writing to sample.json
with open("results/bigger4_p2.json", "w") as outfile:
    json.dump(bigger_plot_data4, outfile)


for i in range(35,40,5):
    print(i)
    bigger_plot_data4.append(trial_permutatin(real_data4,categorical_values4,continuous_values4,cv,reps=i,nr_cols_to_test=4))
# Writing to sample.json
with open("results/bigger4_p3.json", "w") as outfile:
    json.dump(bigger_plot_data4, outfile)
# Out:
# run nr 0 ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# reps 1
# {'Class': 1.0190476190476192, 'T3': 0.732910714896528, 'TST': 0.7264680835652874, 'TSTRI': 1.2285872643458648, 'TSH': 2.35916959339988, 'TMAX': 1.0140596721521522}
# {'Class': 1.0190476190476192, 'T3': 0.732910714896528, 'TST': 0.7264680835652874, 'TSTRI': 1.2285872643458648, 'TSH': 2.35916959339988, 'TMAX': 1.0140596721521522}
# reps 2
# {'Class': 1.0190476190476192, 'T3': 0.732910714896528, 'TST': 0.7264680835652874, 'TSTRI': 1.2285872643458648, 'TSH': 2.35916959339988, 'TMAX': 1.0140596721521522}
# {'Class': 1.0190476190476192, 'T3': 0.732910714896528, 'TST': 0.7264680835652874, 'TSTRI': 1.2285872643458648, 'TSH': 2.35916959339988, 'TMAX': 1.0140596721521522}
# reps 3
# {'Class': 1.0190476190476192, 'T3': 0.732910714896528, 'TST': 0.7264680835652874, 'TSTRI': 1.2285872643458648, 'TSH': 2.35916959339988, 'TMAX': 1.0140596721521522}
# ...

# %%
bigger_plot_data6=[]
for i in range(5,20,5):
    #print(i)
    bigger_plot_data6.append(trial_permutatin(real_data6,categorical_values6,continuous_values6,cv,reps=i))
# Out:
# run nr 0 ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# reps 1
# {'class': 1.9538948978477002, 'age': 1.7463126843657817, 'sex': 1.255693215339233, 'histologic-type': 1.178010190399571, 'degree-of-diffe': 1.3676588897827835, 'bone': 1.3443795895311617, 'bone-marrow': 1.0368958475153165, 'lung': 1.2895069532237673, 'pleura': 1.4709931170108161, 'peritoneum': 1.238938053097345, 'liver': 1.343080672053354, 'brain': 1.1343708676635134, 'skin': 1.103244837758112, 'neck': 1.1343708676635134, 'supraclavicular': 1.3247295968534905, 'axillar': 1.1542721109558556, 'mediastinum': 1.3247295968534905, 'abdominal': 1.2516814159292033}
# ...

# %%
# Writing to sample.json
with open("results/bigger6_p1.json", "w") as outfile:
    json.dump(bigger_plot_data6, outfile)


for i in range(20,35,5):
    print(i)
    bigger_plot_data6.append(trial_permutatin(real_data6,categorical_values6,continuous_values6,cv,reps=i))
# Writing to sample.json
with open("results/bigger6_p2.json", "w") as outfile:
    json.dump(bigger_plot_data6, outfile)


for i in range(35,40,5):
    print(i)
    bigger_plot_data6.append(trial_permutatin(real_data6,categorical_values6,continuous_values6,cv,reps=i))
# Writing to sample.json
with open("results/bigger6_p3.json", "w") as outfile:
    json.dump(bigger_plot_data6, outfile)
# Out:
# 20
# run nr 0 ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# reps 1
# {'class': 1.9538948978477002, 'age': 1.7021491782553733, 'sex': 1.2996558505408062, 'histologic-type': 1.2546705998033432, 'degree-of-diffe': 1.3676588897827835, 'bone': 1.2757522123893805, 'bone-marrow': 1.0368958475153165, 'lung': 1.501978559608605, 'pleura': 1.4414488577896687, 'peritoneum': 1.1997551065842933, 'liver': 1.2310717797443462, 'brain': 1.1185440727963603, 'skin': 1.1185440727963603, 'neck': 1.1507529886663561, 'supraclavicular': 1.3247295968534905, 'axillar': 1.1542721109558556, 'mediastinum': 1.3017879718258984, 'abdominal': 1.2954768928220255}
# ...
